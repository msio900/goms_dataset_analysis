# %%
# !pip install lightgbm
# !pip install pydotplus
# !pip install graphviz
# plot_importance( )를 이용하여 feature 중요도 시각화

# !pip install matplotlib

# %%
from sklearn import tree

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score # 정확도 함수

from xgboost import plot_importance
from xgboost import XGBClassifier

from lightgbm import LGBMClassifier

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, confusion_matrix

# %%
dataset = pd.read_csv('./data/goms_feature_prep_com_mid.csv') # 각자 경로로 바꾸기
dataset
# Out:
#        jobsearch  yrwish  wishhr  wishsalary  jobgradu  liveexp  schooltype  \
# 0              2       2       0           0         2        1           1
# 1              1       2       3        2400         2       -1           1
# 2              2       2       0           0         2        3           1
# 3              2       2       0           0         2        1           1
# 4              2       2       0           0         2        1           1
# ...          ...     ...     ...         ...       ...      ...         ...
# 18158          2       2       0           0         1       -1           2
# 18159          2       2       0           0         2        1           2
# 18160          2       2       0           0         1        1           2
# 18161          2       2       2        3000         2       -1           1
# 18162          2       2       0           0         2        2           1
#
#        majorcate  age  intern  toeic  tosp  train  jobseek  cert  midJobCate
# 0              1   23       0      0     0      0        1     0          20
# 1              1   21       0      0     0    240        1     0           0
# 2              1   21       0    800     0      0        0     1           9
# 3              1   25       0      0     0      0        0     0          18
# 4              1   21       0      0     0      0        1     1          23
# ...          ...  ...     ...    ...   ...    ...      ...   ...         ...
# 18158        181   27       0      0     0      0        1     0           0
# 18159        181   25       0      0     0      0        0     0           9
# 18160        181   26       0      0     0      0        0     0          23
# 18161         20   28       0      0     0      0        0     0           0
# 18162         20   27       0      0     0      0        0     1           9
#
# [18163 rows x 16 columns]

# %%
y_main = dataset['midJobCate']
x_main = dataset.drop(['midJobCate'],axis=1)
X_train, X_test, y_train, y_test = train_test_split(x_main, y_main, test_size=0.3, random_state=0)

# %% [markdown]
# # 디시전트리

# %%
# 데이터 표준화 작업
sc = StandardScaler()
sc.fit(X_train)

# 표준화된 데이터셋
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %%
dataset_tree = tree.DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)
dataset_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)

# %%
from sklearn.metrics import accuracy_score

y_pred_tr = dataset_tree.predict(X_test)
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred_tr))
# Out:
# Accuracy: 0.46

# %%
import os 
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'

# %%
from sklearn.tree import export_graphviz
import pydotplus
from IPython.display import Image


dot_data = export_graphviz(dataset_tree, out_file=None, feature_names=['jobsearch',	'yrwish',	'wishhr',	'wishsalary',	'jobgradu',	'liveexp',	'schooltype',	'majorcate',	'age',	'intern',	'toeic',	'tosp',	'train',	'jobseek',	'cert'],
                          class_names=str(dataset['midJobCate']), filled=True, rounded=True, special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %% [markdown]
# # 랜덤포레스트

# %%
dataset_forest = RandomForestClassifier(n_estimators=20, max_depth=5,random_state=0)
dataset_forest.fit(X_train,y_train)

y_pred_forest = dataset_forest.predict(X_train)
print('Accuracy: %.2f' % accuracy_score(y_train, y_pred_forest))
# Out:
# Accuracy: 0.49

# %%
y_pred_forest = dataset_forest.predict(X_test)
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred_forest))
# Out:
# Accuracy: 0.48

# %% [markdown]
# # XGBoost

# %%
dataset_xgb = XGBClassifier(n_estimators=500, learning_rate = 0.1, max_depth = 4)
dataset_xgb.fit(X_train, y_train)
xgb_pred = dataset_xgb.predict(X_test)
# Out:
# [17:11:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\python\python36\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %%
print('Accuracy: %.2f' % accuracy_score(y_test, xgb_pred))
# Out:
# Accuracy: 0.61

# %% [markdown]
# # LightGBM

# %%
lgbm_wrapper = LGBMClassifier(n_estimators=400)

# LightGBM도 XGBoost와 동일하게 조기 중단 수행 가능. 
evals = [(X_test, y_test)]
lgbm_wrapper.fit(X_train, y_train, early_stopping_rounds=100, eval_metric="logloss", 
                 eval_set=evals, verbose=True)
y_train_pred = lgbm_wrapper.predict(X_train)
pred_proba = lgbm_wrapper.predict_proba(X_test)[:, 1]
# Out:
# [1]	valid_0's multi_logloss: 2.2159
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 2.0065
# [3]	valid_0's multi_logloss: 1.88672
# [4]	valid_0's multi_logloss: 1.79647
# [5]	valid_0's multi_logloss: 1.72919
# [6]	valid_0's multi_logloss: 1.67553
# [7]	valid_0's multi_logloss: 1.63266
# [8]	valid_0's multi_logloss: 1.59579
# [9]	valid_0's multi_logloss: 1.56591
# [10]	valid_0's multi_logloss: 1.54377
# [11]	valid_0's multi_logloss: 1.52587
# [12]	valid_0's multi_logloss: 1.51112
# [13]	valid_0's multi_logloss: 1.49791
# [14]	valid_0's multi_logloss: 1.48744
# [15]	valid_0's multi_logloss: 1.47953
# [16]	valid_0's multi_logloss: 1.47218
# [17]	valid_0's multi_logloss: 1.46606
# [18]	valid_0's multi_logloss: 1.46197
# [19]	valid_0's multi_logloss: 1.45812
# [20]	valid_0's multi_logloss: 1.45468
# [21]	valid_0's multi_logloss: 1.45292
# [22]	valid_0's multi_logloss: 1.45107
# [23]	valid_0's multi_logloss: 1.45112
# [24]	valid_0's multi_logloss: 1.45121
# [25]	valid_0's multi_logloss: 1.4507
# [26]	valid_0's multi_logloss: 1.45151
# [27]	valid_0's multi_logloss: 1.45284
# [28]	valid_0's multi_logloss: 1.45459
# [29]	valid_0's multi_logloss: 1.4558
# [30]	valid_0's multi_logloss: 1.45687
# [31]	valid_0's multi_logloss: 1.45853
# [32]	valid_0's multi_logloss: 1.46017
# [33]	valid_0's multi_logloss: 1.46201
# [34]	valid_0's multi_logloss: 1.46345
# [35]	valid_0's multi_logloss: 1.46504
# [36]	valid_0's multi_logloss: 1.46653
# [37]	valid_0's multi_logloss: 1.4684
# [38]	valid_0's multi_logloss: 1.47037
# [39]	valid_0's multi_logloss: 1.47166
# [40]	valid_0's multi_logloss: 1.47365
# [41]	valid_0's multi_logloss: 1.47698
# [42]	valid_0's multi_logloss: 1.47933
# [43]	valid_0's multi_logloss: 1.48166
# [44]	valid_0's multi_logloss: 1.4845
# [45]	valid_0's multi_logloss: 1.48697
# [46]	valid_0's multi_logloss: 1.48865
# [47]	valid_0's multi_logloss: 1.49079
# [48]	valid_0's multi_logloss: 1.49306
# [49]	valid_0's multi_logloss: 1.49591
# [50]	valid_0's multi_logloss: 1.49834
# [51]	valid_0's multi_logloss: 1.50076
# [52]	valid_0's multi_logloss: 1.50307
# [53]	valid_0's multi_logloss: 1.50513
# [54]	valid_0's multi_logloss: 1.50798
# [55]	valid_0's multi_logloss: 1.51068
# [56]	valid_0's multi_logloss: 1.51325
# [57]	valid_0's multi_logloss: 1.51584
# [58]	valid_0's multi_logloss: 1.51858
# [59]	valid_0's multi_logloss: 1.52117
# [60]	valid_0's multi_logloss: 1.52442
# [61]	valid_0's multi_logloss: 1.5277
# [62]	valid_0's multi_logloss: 1.53039
# [63]	valid_0's multi_logloss: 1.53376
# [64]	valid_0's multi_logloss: 1.53661
# [65]	valid_0's multi_logloss: 1.53977
# [66]	valid_0's multi_logloss: 1.5427
# [67]	valid_0's multi_logloss: 1.54601
# [68]	valid_0's multi_logloss: 1.54894
# [69]	valid_0's multi_logloss: 1.55109
# [70]	valid_0's multi_logloss: 1.5545
# [71]	valid_0's multi_logloss: 1.55799
# [72]	valid_0's multi_logloss: 1.56128
# [73]	valid_0's multi_logloss: 1.56487
# [74]	valid_0's multi_logloss: 1.56829
# [75]	valid_0's multi_logloss: 1.57144
# [76]	valid_0's multi_logloss: 1.57518
# [77]	valid_0's multi_logloss: 1.57853
# [78]	valid_0's multi_logloss: 1.58195
# [79]	valid_0's multi_logloss: 1.58486
# [80]	valid_0's multi_logloss: 1.58804
# [81]	valid_0's multi_logloss: 1.5914
# [82]	valid_0's multi_logloss: 1.59471
# [83]	valid_0's multi_logloss: 1.59837
# [84]	valid_0's multi_logloss: 1.60177
# [85]	valid_0's multi_logloss: 1.60446
# [86]	valid_0's multi_logloss: 1.60732
# [87]	valid_0's multi_logloss: 1.61059
# [88]	valid_0's multi_logloss: 1.61404
# [89]	valid_0's multi_logloss: 1.61739
# [90]	valid_0's multi_logloss: 1.62092
# [91]	valid_0's multi_logloss: 1.62406
# [92]	valid_0's multi_logloss: 1.62759
# [93]	valid_0's multi_logloss: 1.63057
# [94]	valid_0's multi_logloss: 1.63437
# [95]	valid_0's multi_logloss: 1.63822
# [96]	valid_0's multi_logloss: 1.64186
# [97]	valid_0's multi_logloss: 1.6455
# [98]	valid_0's multi_logloss: 1.64904
# [99]	valid_0's multi_logloss: 1.65314
# [100]	valid_0's multi_logloss: 1.65587
# [101]	valid_0's multi_logloss: 1.65933
# [102]	valid_0's multi_logloss: 1.66232
# [103]	valid_0's multi_logloss: 1.66587
# [104]	valid_0's multi_logloss: 1.66926
# [105]	valid_0's multi_logloss: 1.67245
# [106]	valid_0's multi_logloss: 1.67588
# [107]	valid_0's multi_logloss: 1.67926
# [108]	valid_0's multi_logloss: 1.68261
# [109]	valid_0's multi_logloss: 1.6856
# [110]	valid_0's multi_logloss: 1.68893
# [111]	valid_0's multi_logloss: 1.69241
# [112]	valid_0's multi_logloss: 1.6953
# [113]	valid_0's multi_logloss: 1.69927
# [114]	valid_0's multi_logloss: 1.70307
# [115]	valid_0's multi_logloss: 1.70613
# [116]	valid_0's multi_logloss: 1.70945
# [117]	valid_0's multi_logloss: 1.7123
# [118]	valid_0's multi_logloss: 1.71585
# [119]	valid_0's multi_logloss: 1.71938
# [120]	valid_0's multi_logloss: 1.72235
# [121]	valid_0's multi_logloss: 1.72537
# [122]	valid_0's multi_logloss: 1.72878
# [123]	valid_0's multi_logloss: 1.73203
# [124]	valid_0's multi_logloss: 1.73548
# [125]	valid_0's multi_logloss: 1.73848
# Early stopping, best iteration is:
# [25]	valid_0's multi_logloss: 1.4507

# %%
from sklearn.metrics import accuracy_score
y_test_pred = lgbm_wrapper.predict(X_test)
print('Accuracy: %.2f' % accuracy_score(y_test,y_test_pred))
# Out:
# Accuracy: 0.60

# %%
# plot_importance( )를 이용하여 feature 중요도 시각화
from lightgbm import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 10))
plot_importance(lgbm_wrapper, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
df = pd.DataFrame(y_test)

# %%
df['predict'] = lgbm_wrapper.predict(X_test)
df

# %%
df.to_excel('./data/predict.xlsx')

# %%
df = pd.DataFrame(y_test)
df

# %%
get_clf_eval(y_test, preds, pred_proba)
